# %% [markdown]
# <a href="https://colab.research.google.com/github/pavam123/Capstone-project-of-Hotel-Booking-Analysis/blob/main/pavan_web_scrapping_Numerical_Programming_in_Python_Analyze_it_Yourself.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Problem Statement: Navigating the Data Science Job Landscape**
#
# 🚀 Unleash your creativity in crafting a solution that taps into the heartbeat of the data science job market! Envision an ingenious project that seamlessly wields cutting-edge web scraping techniques and illuminating data analysis.
#
# 🔍 Your mission? To engineer a tool that effortlessly gathers job listings from a multitude of online sources, extracting pivotal nuggets such as job descriptions, qualifications, locations, and salaries.
#
# 🧩 However, the true puzzle lies in deciphering this trove of data. Can your solution discern patterns that spotlight the most coveted skills? Are there threads connecting job types to compensation packages? How might it predict shifts in industry demand?
#
# 🎯 The core objectives of this challenge are as follows:
#
# 1. Web Scraping Mastery: Forge an adaptable and potent web scraping mechanism. Your creation should adeptly harvest data science job postings from a diverse array of online platforms. Be ready to navigate evolving website structures and process hefty data loads.
#
# 2. Data Symphony: Skillfully distill vital insights from the harvested job listings. Extract and cleanse critical information like job titles, company names, descriptions, qualifications, salaries, locations, and deadlines. Think data refinement and organization.
#
# 3. Market Wizardry: Conjure up analytical tools that conjure meaningful revelations from the gathered data. Dive into the abyss of job demand trends, geographic distribution, salary variations tied to experience and location, favored qualifications, and emerging skill demands.
#
# 4. Visual Magic: Weave a tapestry of visualization magic. Design captivating charts, graphs, and visual representations that paint a crystal-clear picture of the analyzed data. Make these visuals the compass that guides users through job market intricacies.
#
# 🌐 While the web scraping universe is yours to explore, consider these platforms as potential stomping grounds:
#
# * LinkedIn Jobs
# * Indeed
# * Naukri
# * Glassdoor
# * AngelList
#
# 🎈 Your solution should not only decode the data science job realm but also empower professionals, job seekers, and recruiters to harness the dynamic shifts of the industry. The path is open, the challenge beckons – are you ready to embark on this exciting journey?

# %% [markdown]
# **Send a HTTP Request to Fetch the HTML Content of the Page**

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.linkedin.com/jobs/search/?currentJobId=3761416060&keywords=data%20analyst&origin=JOBS_HOME_KEYWORD_AUTOCOMPLETE&refresh=true"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="d_jobs_guest_search" name="pageKey"/>
#   <!-- -->
#   <meta content="urlType=jserp_custom;emptyResult=false" name="linkedin:pageTag"/>
#   <meta content="en_US" name="locale"/>
#   <meta data-app-version="2.0.1657" data-browser-id="ebc07951-7760-478b-8653-5e047394e9c6" data-call-tree-id="AAYVe7475illr4DdG4ZcaQ==" data-disable-jsbeacon-pagekey-suffix="false" data-enable-page-view-heartbeat-tracking="" data-member-id="0" data-multiproduct-name="jobs-guest-frontend" data-page-instance="urn:li:page:d_jobs_guest_search;PDs5aklxQAKXPOs9mpR8/w==" data-service-name="jobs-guest-frontend" id="config"/>
#   <link href="https://www.linkedin.com/jobs/data-analyst-jobs" rel="canonical"/>
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <link href="https://static.licdn.com/aero-v1/sc/h/al2o9zrvru7aqj8e1x2rzsrca" rel="icon"/>
#   <script>
# ...

# %%
job_titles = [title.text.strip() for title in soup.find_all('h3', class_='base-search-card__title')]

# Extract Company from LinkedIn
company_title=[company.text.strip() for company in soup.find_all('h4',class_='base-search-card__subtitle')]

# Extract Location from LinkedIn
location_title=[location.text.strip() for location in soup.find_all('span',class_='job-search-card__location')]

# Extract Time from LinkedIn
uploaded=[time.text.strip() for time in soup.find_all('time', class_='job-search-card__listdate')]


# Extract Company from LinkedIn
job_link=[link['href'] for link in soup.find_all('a',class_='base-card__full-link')]


# Print the cleaned job titles for verification
print(job_titles)
print(company_title)
print(location_title)
print(uploaded)
print(job_link)
# Out:
# ['Entry Level Data Analyst', 'Data Analyst', 'Data Analyst, Regional Analytics and Insights', 'Junior Data Analyst, Guest Experience, Burger King', 'Data Analyst, Product', 'Data Analyst', 'Data Analyst', 'Sales Data Analyst', 'Data Analyst II', 'Data Analyst', 'Data Analyst, New Product Introduction Team', 'BI, Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst- Freelance (Remote)', 'Data Analyst', 'Data Analyst', 'Junior Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst I', 'Data Analyst', 'Data Analyst', 'Data Analyst (Remote)', 'Data Analyst', 'Business Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst, Product', 'Data Analyst', 'Data Analyst Junior', 'Data Analyst', 'Data Analyst', 'Junior Data Analyst', 'Data Analyst', 'Data Analyst', 'Client Data Analyst I', 'FP&A Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Business
# ...

# %%
import csv
rows=zip(job_titles,company_title,location_title,uploaded,job_link)

#as per the instruction we are making a csv file to store the data extracted from the linkedin
rows=zip(job_titles,company_title,location_title,uploaded,job_link)
# Open the CSV file in write mode
with open('C:\\Users\\ADMIN\\Desktop\\file manager\\WebScrappedData.csv', 'w', newline='', encoding='utf-8') as file:
    # Create a CSV writer object
    writer = csv.writer(file)

    # Write a header if needed
    writer.writerow(['Job Title','company_titles','location_title','uploaded','job_link'])
    # Write the cleaned job titles to the CSV file
    for row in rows:
        writer.writerow(row)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

file_path='C:\\Users\\ADMIN\\Desktop\\file manager\\WebScrappedData.csv'
web=pd.read_csv(file_path)
a=pd.DataFrame(web)
a
# Out:
#                                             Job Title  \
# 0                            Entry Level Data Analyst
# 1                                        Data Analyst
# 2       Data Analyst, Regional Analytics and Insights
# 3   Junior Data Analyst, Guest Experience, Burger ...
# 4                               Data Analyst, Product
# 5                                        Data Analyst
# 6                                        Data Analyst
# 7                                  Sales Data Analyst
# 8                                     Data Analyst II
# 9                                        Data Analyst
# 10        Data Analyst, New Product Introduction Team
# 11                                   BI, Data Analyst
# 12                                       Data Analyst
# 13                                       Data Analyst
# 14                   Data Analyst- Freelance (Remote)
# 15                                       Data Analyst
# ...

# %%
# visualizing job roles on the graph
plt.figure(figsize=(18, 15))
sns.lineplot(data=web, y='Job Title', x='company_titles',marker='o')
plt.title('visualizing job roles on this graph')
plt.xlabel('companies')
plt.legend('Job Titles')
plt.ylabel('Jobs')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Assuming location_counts is a dictionary where keys are locations and values are counts
location_counts = {'Location1': 20, 'Location2': 30, 'Location3': 15}

# Check the type of location_counts
print(type(location_counts))

# Convert location_counts to a Pandas Series if it's a NumPy array (if needed)
# Note: It seems there's an error in the conversion code. I'll correct it.
if isinstance(location_counts, np.ndarray):
    location_counts = pd.Series(location_counts)

# Now proceed with extracting keys and values and plotting the pie chart
locations = list(location_counts.keys())  # Use location_counts instead of location_title
counts = list(location_counts.values())  # Use location_counts instead of location_title

plt.figure(figsize=(10, 10))
sns.set(style="whitegrid")
plt.pie(counts, labels=locations, autopct='%1.1f%%', startangle=140)
plt.title('Geographic distribution of Jobs')
plt.show()
# Out:
# <class 'dict'>

# %%
#problem statementt-- Job seeker want to know the job time uploaded according to the comapany

# so the below code helps the job seeker to see the job uploaded by companies
plt.figure(figsize=(35, 30))
sns.lineplot(data=web, y='uploaded', x='company_titles',hue=None,style=None,marker='o', dashes=False)
plt.title('Job Demand Trends Over Time')
plt.xlabel('Job profiles')
plt.legend('Job Titles')
plt.ylabel('duration of Jobs')
plt.xticks(rotation=45)
plt.show()

# %%
web.columns
# Out:
# Index(['Job Title', 'company_titles', 'location_title', 'uploaded',
#        'job_link'],
#       dtype='object')

# %%
# Locations of job
web['location_title']
# Out:
# 0                          United States
# 1                             Irving, TX
# 2                          San Diego, CA
# 3                              Miami, FL
# 4                          United States
# 5              California, United States
# 6                            Herndon, VA
# 7                          United States
# 8                          San Bruno, CA
# 9        New York City Metropolitan Area
# 10                            Austin, TX
# 11                            Dallas, TX
# 12             New Jersey, United States
# 13                         Sunnyvale, CA
# 14                           Seattle, WA
# 15                       Culver City, CA
# 16                        Buena Park, CA
# 17                     San Francisco, CA
# 18                       Bentonville, AR
# 19             California, United States
# 20                          New York, NY
# 21          Massachusetts, United States
# 22           Pennsylvania, United States
# ...

# %%
# job link
web['job_link']
# Out:
# 0     https://www.linkedin.com/jobs/view/entry-level...
# 1     https://www.linkedin.com/jobs/view/data-analys...
# 2     https://www.linkedin.com/jobs/view/data-analys...
# 3     https://www.linkedin.com/jobs/view/junior-data...
# 4     https://www.linkedin.com/jobs/view/data-analys...
# 5     https://www.linkedin.com/jobs/view/data-analys...
# 6     https://www.linkedin.com/jobs/view/data-analys...
# 7     https://www.linkedin.com/jobs/view/sales-data-...
# 8     https://www.linkedin.com/jobs/view/data-analys...
# 9     https://www.linkedin.com/jobs/view/data-analys...
# 10    https://www.linkedin.com/jobs/view/data-analys...
# 11    https://www.linkedin.com/jobs/view/bi-data-ana...
# 12    https://www.linkedin.com/jobs/view/data-analys...
# 13    https://www.linkedin.com/jobs/view/data-analys...
# 14    https://www.linkedin.com/jobs/view/data-analys...
# 15    https://www.linkedin.com/jobs/view/data-analys...
# 16    https://www.linkedin.com/jobs/view/data-analys...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have location data in a DataFrame 'df' with a column 'Location'
# Count the occurrences of each location
location_counts = web['location_title'].value_counts()

# Plotting the pie chart for geographic distribution of jobs
plt.figure(figsize=(10, 10))
sns.set(style="whitegrid")
plt.pie(location_counts.values, labels=location_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Geographic distribution of Jobs')
plt.show()
